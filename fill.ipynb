# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"D:\ML\WsCubeTech\data\loan\df1_loan.csv")
dataset.head(15)
# Out:
#     Unnamed: 0   Loan_ID Gender Married Dependents     Education  \
# 0            0  LP001002   Male      No          0      Graduate
# 1            1  LP001003   Male     Yes          1      Graduate
# 2            2  LP001005   Male     Yes          0      Graduate
# 3            3  LP001006   Male     Yes          0  Not Graduate
# 4            4  LP001008   Male      No          0      Graduate
# 5            5  LP001011   Male     Yes          2      Graduate
# 6            6  LP001013   Male     Yes          0  Not Graduate
# 7            7  LP001014   Male     Yes         3+      Graduate
# 8            8  LP001018   Male     Yes          2      Graduate
# 9            9  LP001020   Male     Yes          1      Graduate
# 10          10  LP001024   Male     Yes          2      Graduate
# 11          11  LP001027   Male     Yes          2      Graduate
# 12          12  LP001028   Male     Yes          2      Graduate
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# Loan_ID               0
# Gender                9
# Married               3
# Dependents           12
# Education             0
# Self_Employed        27
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           18
# Loan_Amount_Term     14
# Credit_History       41
# Property_Area         0
# Loan_Status           0
# Total_Income          0
# dtype: int64

# %%
dataset.fillna(10) #Fill with 10 and it's a wrong way
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0             0  LP001002    Male      No          0      Graduate
# 1             1  LP001003    Male     Yes          1      Graduate
# 2             2  LP001005    Male     Yes          0      Graduate
# 3             3  LP001006    Male     Yes          0  Not Graduate
# 4             4  LP001008    Male      No          0      Graduate
# ..          ...       ...     ...     ...        ...           ...
# 495         495  LP002586  Female     Yes          1      Graduate
# 496         496  LP002587    Male     Yes          0  Not Graduate
# 497         497  LP002588    Male     Yes          0      Graduate
# 498         498  LP002600    Male     Yes          1      Graduate
# 499         499  LP002602    Male      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5849                0.0        10.0
# ...

# %%
dataset.fillna(10).head(15).isnull().sum() #To check the null value
# Out:
# Unnamed: 0           0
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# Total_Income         0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         500 non-null    int64
#  1   Loan_ID            500 non-null    object
#  2   Gender             491 non-null    object
#  3   Married            497 non-null    object
#  4   Dependents         488 non-null    object
#  5   Education          500 non-null    object
#  6   Self_Employed      473 non-null    object
#  7   ApplicantIncome    500 non-null    int64
#  8   CoapplicantIncome  500 non-null    float64
#  9   LoanAmount         482 non-null    float64
#  10  Loan_Amount_Term   486 non-null    float64
#  11  Credit_History     459 non-null    float64
#  12  Property_Area      500 non-null    object
#  13  Loan_Status        500 non-null    object
#  14  Total_Income       500 non-null    object
# dtypes: float64(4), int64(2), object(9)
# ...

# %%
dataset.fillna(method="bfill") #Backword filling most used in categorial data
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_13564\1866807280.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="bfill") #Backword filling
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0             0  LP001002    Male      No          0      Graduate
# 1             1  LP001003    Male     Yes          1      Graduate
# 2             2  LP001005    Male     Yes          0      Graduate
# 3             3  LP001006    Male     Yes          0  Not Graduate
# 4             4  LP001008    Male      No          0      Graduate
# ..          ...       ...     ...     ...        ...           ...
# 495         495  LP002586  Female     Yes          1      Graduate
# 496         496  LP002587    Male     Yes          0  Not Graduate
# 497         497  LP002588    Male     Yes          0      Graduate
# ...

# %%
dataset["Gender"].mode()[0] #To calculate most frequent term
dataset["Gender"].fillna(dataset["Gender"].mode()[0],inplace=True)

# %%
# dataset["Gender"].isnull().sum()
dataset["Self_Employed"].isnull().sum()
# Out:
# 27

# %%
dataset.select_dtypes(include="object").isnull().sum()
# Out:
# Loan_ID           0
# Gender            0
# Married           3
# Dependents       12
# Education         0
# Self_Employed    27
# Property_Area     0
# Loan_Status       0
# Total_Income      0
# dtype: int64

# %%
 #To get colums name
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status', 'Total_Income'],
#       dtype='object')

# %%
for i in dataset.select_dtypes(include="object").columns: #Loop over the object name
    print(i)
# Out:
# Loan_ID
# Gender
# Married
# Dependents
# Education
# Self_Employed
# Property_Area
# Loan_Status
# Total_Income

# %%
for i in dataset.select_dtypes(include="object").columns: #Loop over the object name
    dataset[i].fillna(dataset[i].mode()[0],inplace=True)
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_13564\2252472243.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset[i].fillna(dataset[i].mode()[0],inplace=True)

# %%
dataset.select_dtypes(include="object").isnull().sum()
# Out:
# Loan_ID          0
# Gender           0
# Married          0
# Dependents       0
# Education        0
# Self_Employed    0
# Property_Area    0
# Loan_Status      0
# Total_Income     0
# dtype: int64
