# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# Generate random data
cgpa = np.random.uniform(6.0, 10.0, 1000)  # CGPA between 6.0 and 10.0
score = np.random.randint(60, 101, 1000)   # Scores between 60 and 100
placed = np.random.choice([1, 0], 1000)  # Random boolean values

# Create DataFrame
data = {
    'cgpa': cgpa,
    'score': score,
    'placed': placed
}

dataset = pd.DataFrame(data)

# Display first 5 rows of the DataFrame
print(dataset.head(5))
# Out:
#        cgpa  score  placed
# 0  9.740004     87       1
# 1  7.672135     61       1
# 2  7.879000     62       0
# 3  7.483529     84       1
# 4  8.962425     77       1

# %%
sns.scatterplot(x="cgpa",y="score",data=dataset,hue="placed")
plt.legend(loc=1)
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["placed"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100 #poor result
# Out:
# 44.0

# %%
lr.predict([[9.740004,87]])
# Out:
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.show()
# Out:
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
#In this code i have to use polynomial features
