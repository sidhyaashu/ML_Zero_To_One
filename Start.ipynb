# %%
import pandas as pd #Import pandas
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("D:\ML\WsCubeTech\data\loan\df1_loan.csv") #To load csv file
dataset.head(10) #display given numbers of data from top
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\ashut\AppData\Local\Temp\ipykernel_3268\3551582471.py:1: SyntaxWarning: invalid escape sequence '\M'
#   dataset = pd.read_csv("D:\ML\WsCubeTech\data\loan\df1_loan.csv")
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
# 5           5  LP001011   Male     Yes          2      Graduate           Yes
# 6           6  LP001013   Male     Yes          0  Not Graduate            No
# ...

# %%
dataset.shape #To count rpw and colums
# Out:
# (500, 15)

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100 #Percentance of null value in overall dataset
# Out:
# 1.6533333333333333

# %%
dataset.isnull() #If null return true and remaining false
# Out:
#      Unnamed: 0  Loan_ID  Gender  Married  Dependents  Education  \
# 0         False    False   False    False       False      False
# 1         False    False   False    False       False      False
# 2         False    False   False    False       False      False
# 3         False    False   False    False       False      False
# 4         False    False   False    False       False      False
# ..          ...      ...     ...      ...         ...        ...
# 495       False    False   False    False       False      False
# 496       False    False   False    False       False      False
# 497       False    False   False    False       False      False
# 498       False    False   False    False       False      False
# 499       False    False   False    False       False      False
#
#      Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            False            False              False        True
# ...

# %%
dataset.isnull().sum() #To count how much null value is present in different colums
# Out:
# Unnamed: 0            0
# Loan_ID               0
# Gender                9
# Married               3
# Dependents           12
# Education             0
# Self_Employed        27
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           18
# Loan_Amount_Term     14
# Credit_History       41
# Property_Area         0
# Loan_Status           0
# Total_Income          0
# dtype: int64

# %%
#To calculate persentence null value 
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# Unnamed: 0           0.0
# Loan_ID              0.0
# Gender               1.8
# Married              0.6
# Dependents           2.4
# Education            0.0
# Self_Employed        5.4
# ApplicantIncome      0.0
# CoapplicantIncome    0.0
# LoanAmount           3.6
# Loan_Amount_Term     2.8
# Credit_History       8.2
# Property_Area        0.0
# Loan_Status          0.0
# Total_Income         0.0
# dtype: float64

# %%
dataset.notnull().sum().sum() #Calculate the filled data
# Out:
# 7376

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
#delete colums
dataset.drop(columns=["Credit_History"],inplace=True)

# %%
dataset.dropna(inplace=True) #delete row where missing value is pressent

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.head(5)
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
# 5           5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#   Property_Area Loan_Status Total_Income
# 1         Rural           N      $6091.0
# ...
